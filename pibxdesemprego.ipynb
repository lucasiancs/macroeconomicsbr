# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import quandl
import matplotlib.dates as dates

# %%
crespib = pd.read_csv('https://www.quandl.com/api/v3/datasets/ODA/BRA_NGDP_RPCH.csv?api_key=KL6MAyNseA2phjbrvTzS',index_col='Date',parse_dates=True)

# %%
crespib.head()
# Out:
#             Value
# Date
# 2024-12-31  2.218
# 2023-12-31  2.218
# 2022-12-31  2.218
# 2021-12-31  2.890
# 2020-12-31 -5.303

# %%
crespib.plot()

# %%
pibcapita = pd.read_csv('https://www.quandl.com/api/v3/datasets/ODA/BRA_NGDPDPC.csv?api_key=KL6MAyNseA2phjbrvTzS',index_col='Date',parse_dates=True)

# %%
pibcapita.head()
# Out:
#                Value
# Date
# 2024-12-31  11411.19
# 2023-12-31  10969.01
# 2022-12-31  10546.89
# 2021-12-31  10145.32
# 2020-12-31   9765.50

# %%
pibcapita.plot()

# %%
desemprego = pd.read_csv('https://www.quandl.com/api/v3/datasets/ODA/BRA_LUR.csv?api_key=KL6MAyNseA2phjbrvTzS',index_col='Date',parse_dates=True)

# %%
desemprego.head()
# Out:
#             Value
# Date
# 2024-12-31   9.00
# 2023-12-31   9.25
# 2022-12-31   9.50
# 2021-12-31  13.50
# 2020-12-31  14.70

# %%
desemprego.plot()

# %%
idx1= crespib.index

# %%
idx2 = pibcapita.index

# %%
idx3 = desemprego.index

# %%
datacrespib = crespib['Value']

# %%
datapibcapita = pibcapita['Value']

# %%
datadesemp = desemprego['Value']

# %%
pibxdesemprego, ax = plt.subplots(figsize=(10,3))

ax.plot(idx1,datacrespib,'r',label='Crescimento do PIB',lw=3)
ax.plot(idx3,desemprego,'g',label='Desemprego',lw=3)
ax.yaxis.grid(True,linestyle='dashed',alpha=0.9)
ax.set_xlabel('Data',fontsize=12)
ax.set_ylabel('% de Crescimento',fontsize=12)
ax.set_title('PIB relacionado com a taxa de Desemprego entre 1980 e 2025',fontsize=12)

ax2 = ax.twinx()
ax2.plot(idx2,datapibcapita,'b',label='PIB per capita',lw=2)
ax2.set_ylabel('PIB per capita',fontsize=12)

pibxdesemprego.legend()
plt.show()

# %%
pibxdesemprego.savefig('pibxdesemprego.png')
